# %% [markdown]
# ## Class

# %% [markdown]
# !![image.png](attachment:image.png)

# %%
class Dog:
    pass

# %%
a=Dog()
a.__class__
# Out:
# __main__.Dog

# %% [markdown]
# !![image.png](attachment:image.png)

# %%
class Dog:
    
    def __init__ (self, name, age):
        
        self.name = name
        self.age  = age

# %%
class Dog:
    
    species='mammal'
    
    def __init__ (self, name, age):
        
        self.name = name
        self.age  = age

# %%
a=Dog('vimal','27')
dir(a)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'age',
#  'name']

# %%
a.name
# Out:
# 'vimal'

# %%
Dog.species
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-23-222d3ba50447> in <module>
# ----> 1 Dog.species
#
# AttributeError: type object 'Dog' has no attribute 'species'

# %%
a.age
# Out:
# '27'

# %%
a.__getattribute__
# Out:
# <method-wrapper '__getattribute__' of Dog object at 0x000001E41C76A2C8>

# %%
#####################################################################

# %%
class Dog:
    
    species='mammal'
    
    def __init__ (self, name, age):
        
        self.name = name
        self.age  = age

# %%
philo=Dog('phil',10)
mike=Dog('mik',20)

print(philo.name,philo.age,mike.name,mike.age)
# Out:
# phil 10 mik 20

# %%
if philo.species == 'mammal':
    print(philo.name)
# Out:
# phil

# %%
Dog.species
# Out:
# 'mammal'

# %%
#####################################################################################

# %%
class Dog:
    
    species='mammal'
    
    def __init__ (self, name, age):
        
        self.name = name
        self.age  = age
        
philo=Dog('phil',10)
mike=Dog('mik',20)


philo.species='one dog'

# %%
philo.species
# Out:
# 'one dog'

# %%
mike.species
# Out:
# 'mammal'

# %%
# Out:
# 'vimal has 20 rupees'

# %%
# Out:
# 'vimal this is the sound oooinnnn'

# %%
# Out:
# '21 is the age'
